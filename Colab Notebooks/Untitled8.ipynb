# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torchvision import transforms, datasets

USE_CUDA = torch.cuda.is_available()
DEVICE = torch.device("cuda" if USE_CUDA else "cpu")  #GPU로 보냄

EPOCHS = 30         #모델 학습 수
BATCH_SIZE = 64     #64이라면 64개의 샘플 단위마다 모델의 가중치를 한번씩 업데이트

transform = transforms.Compose([      # 이미지를 텐서로 바꿔줌
  transforms.ToTensor()
])

trainset = datasets.FashionMNIST(
    root = './.data',
    train = True,
    download = True,
    transform = transform
)
testset = datasets.FashionMNIST(
    root = './.data',
    train = False,
    download = True,
    transform = transform
)

train_loader = torch.utils.data.DataLoader(
    dataset = trainset,
    batch_size = BATCH_SIZE,
    shuffle = True,
)

test_loader = torch.utils.data.DataLoader(
    dataset = testset,
    batch_size = BATCH_SIZE,
    shuffle = True,
)

class Net(nn.Module):
  def __init__(self):
    super(Net, self).__init__()
    self.fc1 = nn.Linear(784, 256)  #784픽셀
    self.fc2 = nn.Linear(256, 128)
    self.fc3 = nn.Linear(128, 10)

  def forward(self, x):
    x = x.view(-1, 784)
    x = F.relu(self.fc1(x))
    x = F.relu(self.fc2(x))
    x = self.fc3(x)
    return x

model = Net().to(DEVICE)
optimizer= optim.SGD(model.parameters(), lr=0.01)

def train(model, train_loader, optimizer):
  model.train()
  for batch_idx, (data, target) in enumerate(train_loader):
    data, target = data.to(DEVICE), target.to(DEVICE)
    optimizer.zero_grad()
    output = model(data)
    loss = F.cross_entropy(output, target)
    loss.backward()
    optimizer.step()

def evaluate(model, test_loader):
  model.eval()
  test_loss = 0
  correct = 0
  with torch.no_grad():
    for data, target in test_loader:
        data, target = data.to(DEVICE), target.to(DEVICE)
        output = model(data)

        test_loss += F.cross_entropy(output, target, reduction='sum').item()

        pred = output.max(1, keepdim=True)[1]
        correct += pred.eq(target.view_as(pred)).sum().item()

  test_loss /= len(test_loader.dataset)
  test_accuracy = 100.*correct / len(test_loader.dataset)
  return test_loss, test_accuracy

for epoch in range(1, EPOCHS +1):
  train(model, train_loader, optimizer)
  test_loss, test_accuracy = evaluate(model, test_loader)

  print('[{}] Test Loss: {:.4f}, Accuracy: {:.2f}%'.format(epoch, test_loss, test_accuracy))
# Out:
# [1] Test Loss: 0.8314, Accuracy: 69.47%
# [2] Test Loss: 0.6475, Accuracy: 76.79%
# [3] Test Loss: 0.5789, Accuracy: 79.21%
# [4] Test Loss: 0.5332, Accuracy: 81.07%
# [5] Test Loss: 0.5058, Accuracy: 82.30%
# [6] Test Loss: 0.5068, Accuracy: 81.91%
# [7] Test Loss: 0.4934, Accuracy: 82.95%
# [8] Test Loss: 0.4719, Accuracy: 83.19%
# [9] Test Loss: 0.4591, Accuracy: 83.73%
# [10] Test Loss: 0.4585, Accuracy: 83.52%
# [11] Test Loss: 0.4463, Accuracy: 84.03%
# [12] Test Loss: 0.4622, Accuracy: 83.84%
# [13] Test Loss: 0.4563, Accuracy: 83.24%
# [14] Test Loss: 0.4303, Accuracy: 84.63%
# [15] Test Loss: 0.4344, Accuracy: 84.35%
# [16] Test Loss: 0.4128, Accuracy: 85.48%
# [17] Test Loss: 0.4141, Accuracy: 85.30%
# [18] Test Loss: 0.4037, Accuracy: 85.65%
# [19] Test Loss: 0.4035, Accuracy: 85.83%
# [20] Test Loss: 0.4120, Accuracy: 85.40%
# [21] Test Loss: 0.4169, Accuracy: 84.99%
# [22] Test Loss: 0.3888, Accuracy: 86.24%
# [23] Test Loss: 0.3878, Accuracy: 86.37%
# [24] Test Loss: 0.3905, Accuracy: 86.17%
# [25] Test Loss: 0.3967, Accuracy: 85.92%
# [26] Test Loss: 0.4546, Accuracy: 83.16%
# [27] Test Loss: 0.4110, Accuracy: 85.44%
# [28] Test Loss: 0.3752, Accuracy: 86.56%
# [29] Test Loss: 0.3879, Accuracy: 86.03%
# [30] Test Loss: 0.3675, Accuracy: 87.02%
